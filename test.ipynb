# %%
import pandas as pd

# %%
data = pd.read_csv("research_pipeline/fiinetune_data.csv")
data.head()
# Out:
#    ID                                      Transcription  \
# 0   1  Bạn hãy tìm tên những khách hàng có trình độ '...
# 1   2  Tìm URL của những trang web page đã bán đồ 'Wo...
# 2   3       Lấy thông tin định danh và họ tên khách hàng
# 3   4              Tìm tất cả khách hàng đến từ Việt Nam
# 4   5            Đếm tổng số lượng khách hàng trong bảng
#
#                                     SQL Ground Truth
# 0  SELECT c.c_first_name, c.c_last_name\r\nFROM c...
# 1  SELECT DISTINCT wp.wp_url\r\nFROM web_sales ws...
# 2  SELECT c_customer_id, c_first_name, c_last_nam...
# 3  SELECT * FROM customer \nWHERE c_birth_country...
# 4  SELECT COUNT(*) AS total_customers \nFROM cust...
