# %%
# setup anaconda: conda create -n thesis python=3.12
# activate environment: conda activate thesis
# install dependencies: pip install -r requirements.txt

# %%
import duckdb

# 1. Tạo kết nối tới database
con = duckdb.connect(database=':memory:')

# 2. Cài đặt và load extension TPC-H
con.execute("INSTALL tpch;")
con.execute("LOAD tpch;")

# 3. Sinh dữ liệu (Data Generation)
print("Đang sinh dữ liệu TPC-H, vui lòng đợi...")
# có các phiên bản sf=1, sf=10, sf=30, sf=100, sf=300, sf=1000, sf=3000 với size lần lượt là 250MB, 754MB, 2.5GB, 7.6GB, 26GB, 78GB, 265GB, 796GB
con.execute("CALL dbgen(sf=30);")

print("Đã sinh xong dữ liệu TPC-H!")
# Out:
# Đang sinh dữ liệu TPC-H, vui lòng đợi...
# Đã sinh xong dữ liệu TPC-H!

# %%
# Liệt kê các bảng trong database
con.sql("SHOW TABLES").show()
# Out:
# ┌──────────┐
# │   name   │
# │ varchar  │
# ├──────────┤
# │ customer │
# │ lineitem │
# │ nation   │
# │ orders   │
# │ part     │
# │ partsupp │
# │ region   │
# │ supplier │
# └──────────┘

# %%
# Lấy 5 đơn hàng đầu tiên và tên khách hàng tương ứng
query = """
    SELECT
        c.c_name AS CustomerName,
        o.o_orderdate AS OrderDate,
        o.o_totalprice AS TotalPrice,
        o.o_comment AS OrderComment
    FROM orders o
    JOIN customer c ON o.o_custkey = c.c_custkey
    LIMIT 5;
"""

con.sql(query).show()
# Out:
# ┌────────────────────┬────────────┬───────────────┬──────────────────────────────────────────────────────────────┐
# │    CustomerName    │ OrderDate  │  TotalPrice   │                         OrderComment                         │
# │      varchar       │    date    │ decimal(15,2) │                           varchar                            │
# ├────────────────────┼────────────┼───────────────┼──────────────────────────────────────────────────────────────┤
# │ Customer#000079021 │ 1998-03-10 │      95958.04 │  to the slyly pending asymptotes. packages wake pending, e   │
# │ Customer#000136480 │ 1996-11-30 │      12205.16 │ ove the carefully final                                      │
# │ Customer#000141829 │ 1992-06-25 │     279812.88 │ ate fluffily unusual, unusual theodolit                      │
# │ Customer#000047714 │ 1995-07-05 │       5469.56 │ unusual ideas. even, even packages affix furi                │
# │ Customer#000024700 │ 1996-07-12 │     148527.10 │ y somas. furiously special packages haggle blithely regular  │
# └────────────────────┴────────────┴───────────────┴──────────────────────────────────────────────────────────────┘

# %%
# Chuyển kết quả truy vấn thành Pandas DataFrame
df = con.sql("SELECT * FROM customer LIMIT 10").df()
df
# Out:
#    c_custkey              c_name                              c_address  \
# 0          1  Customer#000000001                      j5JsirBM9PsCy0O1m
# 1          2  Customer#000000002         487LW1dovn6Q4dMVymKwwLE9OKf3QG
# 2          3  Customer#000000003                           fkRGN8nY4pkE
# 3          4  Customer#000000004                            4u58h fqkyE
# 4          5  Customer#000000005           hwBtxkoBF qSW4KrIk5U 2B1AU7H
# 5          6  Customer#000000006    g1s,pzDenUEBW3O,2 pxu0f9n2g64rJrt5E
# 6          7  Customer#000000007         8OkMVLQ1dK6Mbu6WG9 w4pLGQ n7MQ
# 7          8  Customer#000000008  j,pZ,Qp,qtFEo0r0c 92qobZtlhSuOqbE4JGV
# 8          9  Customer#000000009             vgIql8H6zoyuLMFNdAMLyE7 H9
# 9         10  Customer#000000010     Vf mQ6Ug9Ucf5OKGYq fsaX AtfsO7,rwY
#
#    c_nationkey          c_phone  c_acctbal c_mktsegment  \
# 0           15  25-989-741-2988     711.56     BUILDING
# 1           13  23-768-687-3665     121.65   AUTOMOBILE
# 2            1  11-719-748-3364    7498.12   AUTOMOBILE
# 3            4  14-128-190-5944    2866.83    MACHINERY
# 4            3  13-750-942-6364     794.47    HOUSEHOLD
# 5           20  30-114-968-4951    7638.57   AUTOMOBILE
# 6           18  28-190-982-9759    9561.95   AUTOMOBILE
# 7           17  27-147-574-9335    6819.74     BUILDING
# 8            8  18-338-906-3675    8324.07    FURNITURE
# 9            5  15-741-346-9870    2753.54    HOUSEHOLD
#
#                                            c_comment
# 0  y final requests wake slyly quickly special ac...
# 1  y carefully regular foxes. slyly regular reque...
# 2  fully. carefully silent instructions sleep alo...
# 3   sublate. fluffily even instructions are about th
# 4  equests haggle furiously against the pending p...
# 5   quickly silent asymptotes are slyly regular e...
# 6  ounts. ironic, regular accounts sleep. final r...
# 7  riously final excuses sublate quickly among th...
# 8  ss pinto beans believe slyly quiet deposits-- ...
# 9                    g quickly after the evenly bold

# %%
query_nation_8 = """
    SELECT
        c_custkey,
        c_name,
        c_address,
        c_nationkey,
        c_phone,
        c_acctbal,
        c_mktsegment,
        c_comment
    FROM customer
    WHERE c_nationkey = 8;
"""

con.sql(query_nation_8).df().head()
# Out:
#    c_custkey              c_name                              c_address  \
# 0          9  Customer#000000009             vgIql8H6zoyuLMFNdAMLyE7 H9
# 1         21  Customer#000000021                          42E5BARtqjomD
# 2         28  Customer#000000028             J5tK,OQa07KQSuY5b4qRFYVYRF
# 3         37  Customer#000000037                      Um5WbwJ0X8QCOy75y
# 4         91  Customer#000000091  9Sce2m BjvDdjQkqMx8UnrUsJkk1IBAvZPTsA
#
#    c_nationkey          c_phone  c_acctbal c_mktsegment  \
# 0            8  18-338-906-3675    8324.07    FURNITURE
# 1            8  18-902-614-8344    1428.25    MACHINERY
# 2            8  18-774-241-1462    1007.18    FURNITURE
# 3            8  18-385-235-7162    -917.75    FURNITURE
# 4            8  18-239-400-3677    4643.14   AUTOMOBILE
#
#                                            c_comment
# 0  ss pinto beans believe slyly quiet deposits-- ...
# 1  e blithely carefully quick sheaves. furiously ...
# 2   r accounts are quickly. boldly bold foxes haggle
# 3  above the slyly regular accounts sleep along t...
# 4  yly ironic foxes lose slyly pending asymptotes...

# %%
# phân tích data warehouse này: ví dụ có bao nhiêu field, row, bảng, ...
tables = con.sql("SHOW TABLES").df()
for table in tables['name']:
    result = con.sql(f"SELECT COUNT(*) AS row_count FROM {table}").df()
    row_count = result['row_count'][0]
    columns = con.sql(f"DESCRIBE {table}").df()
    column_count = len(columns)
    print(f"Table '{table}' has {row_count} rows and {column_count} columns.")
# Out:
# Table 'customer' has 150000 rows and 8 columns.
# Table 'lineitem' has 6001215 rows and 16 columns.
# Table 'nation' has 25 rows and 4 columns.
# Table 'orders' has 1500000 rows and 9 columns.
# Table 'part' has 200000 rows and 9 columns.
# Table 'partsupp' has 800000 rows and 5 columns.
# Table 'region' has 5 rows and 3 columns.
# Table 'supplier' has 10000 rows and 7 columns.
