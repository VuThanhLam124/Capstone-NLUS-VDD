# %%
# !git clone https://github.com/VuThanhLam124/Capstone-NLUS-VDD.git
# Out:
# Cloning into 'Capstone-NLUS-VDD'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 88 (delta 33), reused 72 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (88/88), 331.23 KiB | 9.74 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
cd Capstone-NLUS-VDD
# Out:
# /kaggle/working/Capstone-NLUS-VDD

# %%
ls
# Out:
# docs/    LICENSE     README.md         research_pipeline/
# images/  notebooks/  requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Collecting duckdb==1.1.3 (from -r requirements.txt (line 1))
#   Downloading duckdb-1.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (762 bytes)
# Collecting openai-whisper (from -r requirements.txt (line 2))
#   Downloading openai_whisper-20250625.tar.gz (803 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 12.5 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jiwer (from -r requirements.txt (line 3))
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting bitsandbytes (from -r requirements.txt (line 4))
#   Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.57.1)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.17.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (1.11.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (1.15.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.13.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (0.11.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (2.2.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.9.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.2.1)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (2.8.0+cu126)
# Collecting edge-tts (from -r requirements.txt (line 15))
#   Downloading edge_tts-7.2.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (0.36.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (1.6.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (22.0.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r requirements.txt (line 2)) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r requirements.txt (line 2)) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r requirements.txt (line 2)) (2.8.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from jiwer->-r requirements.txt (line 3)) (8.3.1)
# Collecting rapidfuzz>=3.9.7 (from jiwer->-r requirements.txt (line 3))
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (3.20.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 5)) (0.6.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft->-r requirements.txt (line 6)) (5.9.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile->-r requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->-r requirements.txt (line 10)) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->-r requirements.txt (line 10)) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->-r requirements.txt (line 10)) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->-r requirements.txt (line 10)) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->-r requirements.txt (line 10)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->-r requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->-r requirements.txt (line 10)) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->-r requirements.txt (line 10)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->-r requirements.txt (line 10)) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 11)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 11)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 11)) (2025.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r requirements.txt (line 2)) (1.11.1.6)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from edge-tts->-r requirements.txt (line 15)) (3.13.2)
# Requirement already satisfied: certifi>=2023.11.17 in /usr/local/lib/python3.12/dist-packages (from edge-tts->-r requirements.txt (line 15)) (2025.11.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->-r requirements.txt (line 16)) (1.2.1rc0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts->-r requirements.txt (line 15)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts->-r requirements.txt (line 15)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts->-r requirements.txt (line 15)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts->-r requirements.txt (line 15)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts->-r requirements.txt (line 15)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts->-r requirements.txt (line 15)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts->-r requirements.txt (line 15)) (1.22.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 9)) (2.23)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper->-r requirements.txt (line 2)) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->-r requirements.txt (line 10)) (4.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 5)) (2.6.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->openai-whisper->-r requirements.txt (line 2)) (3.0.3)
# Downloading duckdb-1.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 48.6 MB/s eta 0:00:0000:0100:01m
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 32.3 MB/s eta 0:00:00:00:0100:01
# Downloading edge_tts-7.2.7-py3-none-any.whl (30 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 87.4 MB/s eta 0:00:00:00:01
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=8592b7d3b85cea6783cc2153a38896c85a6893b2561a61e29053031321ec1ead
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# Installing collected packages: rapidfuzz, duckdb, jiwer, edge-tts, openai-whisper, bitsandbytes
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
# Successfully installed bitsandbytes-0.49.0 duckdb-1.1.3 edge-tts-7.2.7 jiwer-4.0.0 openai-whisper-20250625 rapidfuzz-3.14.3

# %%
# !pip install chunkformer num2words
# Out:
# Collecting chunkformer
#   Downloading chunkformer-1.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting num2words
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: torch>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from chunkformer) (2.8.0+cu126)
# Requirement already satisfied: torchaudio>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from chunkformer) (2.8.0+cu126)
# Requirement already satisfied: transformers>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from chunkformer) (4.57.1)
# Requirement already satisfied: PyYAML>=5.4.0 in /usr/local/lib/python3.12/dist-packages (from chunkformer) (6.0.3)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from chunkformer) (2.2.2)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.12/dist-packages (from chunkformer) (4.67.1)
# Requirement already satisfied: jiwer>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from chunkformer) (4.0.0)
# Requirement already satisfied: colorama>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from chunkformer) (0.4.6)
# Requirement already satisfied: pydub>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from chunkformer) (0.25.1)
# Requirement already satisfied: huggingface_hub>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from chunkformer) (0.36.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from chunkformer) (11.3.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from chunkformer) (0.2.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from chunkformer) (2.19.0)
# Collecting tensorboardX (from chunkformer)
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Collecting textgrid (from chunkformer)
#   Downloading TextGrid-1.6.1.tar.gz (9.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deepspeed>=0.14.0 (from chunkformer)
#   Downloading deepspeed-0.18.3.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.2 MB/s eta 0:00:0000:010:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from chunkformer) (0.11.0)
# Requirement already satisfied: langid in /usr/local/lib/python3.12/dist-packages (from chunkformer) (1.1.6)
# Collecting docopt>=0.6.2 (from num2words)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.14.0->chunkformer) (0.8.1)
# Collecting hjson (from deepspeed>=0.14.0->chunkformer)
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.14.0->chunkformer) (1.1.2)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.14.0->chunkformer) (1.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.14.0->chunkformer) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.14.0->chunkformer) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.14.0->chunkformer) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.14.0->chunkformer) (9.0.0)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.14.0->chunkformer) (2.12.5)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.14.0->chunkformer) (12.575.51)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.10.0->chunkformer) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.10.0->chunkformer) (2025.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.10.0->chunkformer) (2.32.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.10.0->chunkformer) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.10.0->chunkformer) (1.2.1rc0)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from jiwer>=2.3.0->chunkformer) (8.3.1)
# Requirement already satisfied: rapidfuzz>=3.9.7 in /usr/local/lib/python3.12/dist-packages (from jiwer>=2.3.0->chunkformer) (3.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->chunkformer) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->chunkformer) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->chunkformer) (2025.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->chunkformer) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.20.0->chunkformer) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.20.0->chunkformer) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.20.0->chunkformer) (0.6.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->chunkformer) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa->chunkformer) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa->chunkformer) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->chunkformer) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->chunkformer) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->chunkformer) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa->chunkformer) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->chunkformer) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->chunkformer) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->chunkformer) (0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->chunkformer) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->chunkformer) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->chunkformer) (3.9)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->chunkformer) (5.29.5)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard->chunkformer) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->chunkformer) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->chunkformer) (3.1.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa->chunkformer) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->chunkformer) (4.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed>=0.14.0->chunkformer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed>=0.14.0->chunkformer) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed>=0.14.0->chunkformer) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.10.0->chunkformer) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.10.0->chunkformer) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.10.0->chunkformer) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.10.0->chunkformer) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->chunkformer) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa->chunkformer) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.5.1->chunkformer) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->chunkformer) (3.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->chunkformer) (2.23)
# Downloading chunkformer-1.2.2-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.5/150.5 kB 6.3 MB/s eta 0:00:00
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 9.7 MB/s eta 0:00:00
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.1 MB/s eta 0:00:00
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 3.1 MB/s eta 0:00:00
# Building wheels for collected packages: deepspeed, docopt, textgrid
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.18.3-py3-none-any.whl size=1770201 sha256=fd0d403108487b29dca4ff5500d01d32030a53263f8c001abcfe93a28d72df98
#   Stored in directory: /root/.cache/pip/wheels/c9/9a/37/beb534d37a37cd057d48ba20b82f34d527816b7fdf0206882f
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=a4589d50fd6deb4b9cbb895b3582ef829e377a6dc0b18d4f207a19ddcee7ea7a
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
#   Building wheel for textgrid (setup.py) ... done
#   Created wheel for textgrid: filename=TextGrid-1.6.1-py3-none-any.whl size=10146 sha256=594fee2be98fd1598b3109cbf96545c57178c0070438f6e624399535c4ebc670
#   Stored in directory: /root/.cache/pip/wheels/ce/86/7b/5766bd19fa4b4554667dd186e614b5a438ab14eec9c5a3642a
# Successfully built deepspeed docopt textgrid
# Installing collected packages: textgrid, hjson, docopt, tensorboardX, num2words, deepspeed, chunkformer
# Successfully installed chunkformer-1.2.2 deepspeed-0.18.3 docopt-0.6.2 hjson-3.1.0 num2words-0.5.14 tensorboardX-2.6.4 textgrid-1.6.1

# %%
# !python research_pipeline/generate_large_dataset.py

# %%
# !python research_pipeline/kaggle_asr_pipeline.py

# %%
import os
import time
import gc
import torch
import jiwer
import pandas as pd
import numpy as np
import soundfile as sf
import tempfile
import re
from num2words import num2words
from transformers import pipeline

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DATA_PATH = "/kaggle/input/capstone-speech-to-sql/data"
df = pd.read_csv(os.path.join(DATA_PATH, "metadata.csv"))
print(f"Found {len(df)} samples")

def cleanup_gpu():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

def normalize_audio(arr):
    arr = np.asarray(arr, dtype=np.float32)
    max_val = np.abs(arr).max()
    if max_val > 0:
        arr = arr / max_val
    return arr

_PUNCT_RE = re.compile(r"[.,?!;:\"'()\[\]-]")
_NUM_RE = re.compile(r"\d+")

def normalize_text(text):
    text = str(text).lower().strip()
    text = _PUNCT_RE.sub(" ", text)

    def num_to_vn(match):
        try:
            return num2words(int(match.group()), lang="vi")
        except Exception:
            return match.group()

    text = _NUM_RE.sub(num_to_vn, text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

def load_audio_array(path):
    tensor = torch.load(path, map_location="cpu")
    if isinstance(tensor, torch.Tensor):
        tensor = tensor.detach().cpu().numpy()
    return normalize_audio(tensor)

def compute_wer(gt_text, hyp_text):
    gt_norm = normalize_text(gt_text)
    hyp_norm = normalize_text(hyp_text)
    if not gt_norm or not hyp_norm:
        return 1.0, gt_norm, hyp_norm
    return jiwer.wer(gt_norm, hyp_norm), gt_norm, hyp_norm

results = []
# ========== 1. PhoWhisper ==========
print("=" * 50)
print("Loading PhoWhisper-Large...")
cleanup_gpu()
pipe = pipeline(
    "automatic-speech-recognition",
    model="vinai/PhoWhisper-large",
    device=0 if torch.cuda.is_available() else -1
)
for idx, row in df.iterrows():
    arr = load_audio_array(os.path.join(DATA_PATH, "tensors", row["tensor_filename"]))

    start = time.time()
    hyp = pipe({"raw": arr, "sampling_rate": 16000})["text"]
    infer_time = time.time() - start

    wer, gt_norm, hyp_norm = compute_wer(row["text"], hyp)

    results.append({
        "Model": "PhoWhisper-Large",
        "ID": row["id"],
        "GT": row["text"],
        "Hyp": hyp,
        "WER": wer,
        "Time": infer_time
    })

    if idx < 3:
        print(f"[{idx}] WER: {wer:.3f}")
        print(f"    GT: {gt_norm[:70]}")
        print(f"    Hyp: {hyp_norm[:70]}")

del pipe
cleanup_gpu()
# ========== 2. Chunkformer ==========
print("\n" + "=" * 50)
print("Loading Chunkformer-Large...")
try:
    from chunkformer import ChunkFormerModel
    chunkformer = ChunkFormerModel.from_pretrained("khanhld/chunkformer-ctc-large-vie")
    try:
        chunkformer = chunkformer.to(DEVICE)
    except Exception:
        pass

    for idx, row in df.iterrows():
        arr = load_audio_array(os.path.join(DATA_PATH, "tensors", row["tensor_filename"]))

        tmp_path = None
        try:
            with tempfile.NamedTemporaryFile(suffix=".wav", delete=False) as tmp:
                sf.write(tmp.name, arr, 16000)
                tmp_path = tmp.name

            start = time.time()
            hyp = chunkformer.endless_decode(
                audio_path=tmp_path,
                chunk_size=64,
                left_context_size=128,
                right_context_size=128,
                return_timestamps=False
            )
            infer_time = time.time() - start
        finally:
            if tmp_path and os.path.exists(tmp_path):
                os.unlink(tmp_path)

        hyp = hyp if isinstance(hyp, str) else str(hyp)
        wer, gt_norm, hyp_norm = compute_wer(row["text"], hyp)

        results.append({
            "Model": "Chunkformer-Large",
            "ID": row["id"],
            "GT": row["text"],
            "Hyp": hyp,
            "WER": wer,
            "Time": infer_time
        })

        if idx < 3:
            print(f"[{idx}] WER: {wer:.3f}")
            print(f"    GT: {gt_norm[:70]}")
            print(f"    Hyp: {hyp_norm[:70]}")

    del chunkformer
    cleanup_gpu()
except Exception as e:
    print(f"Chunkformer failed: {e}")
    import traceback
    traceback.print_exc()

# ========== 3. OpenAI Whisper Large V3 ==========
print("\n" + "=" * 50)
print("Loading OpenAI Whisper-Large-V3...")
cleanup_gpu()

# Load với float16 để tối ưu GPU memory và tốc độ
pipe_whisper = pipeline(
    "automatic-speech-recognition",
    model="openai/whisper-large-v3",
    device=0 if torch.cuda.is_available() else -1,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    chunk_length_s=30,  # Xử lý audio theo chunk 30s
)

for idx, row in df.iterrows():
    arr = load_audio_array(os.path.join(DATA_PATH, "tensors", row["tensor_filename"]))

    start = time.time()
    # Chỉ định ngôn ngữ tiếng Việt để tăng độ chính xác
    hyp = pipe_whisper(
        {"raw": arr, "sampling_rate": 16000},
        generate_kwargs={
            "language": "vietnamese",  # Hoặc "vi"
            "task": "transcribe"
        }
    )["text"]
    infer_time = time.time() - start

    wer, gt_norm, hyp_norm = compute_wer(row["text"], hyp)

    results.append({
        "Model": "Whisper-Large-V3",
        "ID": row["id"],
        "GT": row["text"],
        "Hyp": hyp,
        "WER": wer,
        "Time": infer_time
    })

    if idx < 3:
        print(f"[{idx}] WER: {wer:.3f}")
        print(f"    GT: {gt_norm[:70]}")
        print(f"    Hyp: {hyp_norm[:70]}")

del pipe_whisper
cleanup_gpu()

# ========== SUMMARY ==========
print("\n" + "=" * 50)
print("BENCHMARK RESULTS")
print("=" * 50)
res_df = pd.DataFrame(results)
res_df.to_csv("/kaggle/working/benchmark_results.csv", index=False)
summary = res_df.groupby("Model")[["WER", "Time"]].agg(["mean", "std"])
print(summary)
# Out:
# 2025-12-27 00:13:08.104623: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766794388.304434      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766794388.359884      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766794388.830370      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766794388.830421      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766794388.830424      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766794388.830427      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 800 samples
# ==================================================
# Loading PhoWhisper-Large...
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/6.17G [00:00<?, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
